# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing Skin Cancer Data
# #### To do: Take necessary actions to read the data

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive')

##Ref:https://towardsdatascience.com/downloading-datasets-into-google-drive-via-google-colab-bcb1b30b0166
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Extract Data Set file in gdrive

# %%
# !ls /content/gdrive/MyDrive/DataSets/
# Out:
# CNN_assignment.zip

# %%
# !unzip /content/gdrive/MyDrive/DataSets/CNN_assignment.zip -d /content/gdrive/MyDrive/DataSets/
print("Extraction Successfull")
# Out:
# Archive:  /content/gdrive/MyDrive/DataSets/CNN_assignment.zip
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010512.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0010889.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024468.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024470.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024511.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024646.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024654.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024707.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024763.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024771.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024800.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024913.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0024948.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025368.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025427.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/actinic keratosis/ISIC_0025605.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024331.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024332.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024345.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024360.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024403.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024411.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024431.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024432.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024436.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024443.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024448.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024452.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024454.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024457.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024461.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/basal cell carcinoma/ISIC_0024472.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001114.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0001130.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011410.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011433.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011478.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011677.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0011865.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024318.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024330.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024386.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024396.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024553.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024845.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024973.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0024994.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/dermatofibroma/ISIC_0025154.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000002.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000004.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000013.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000022.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000026.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000029.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000030.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000031.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000035.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000036.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000040.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000043.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000046.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000049.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000054.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/melanoma/ISIC_0000056.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000000.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000001.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000003.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000005.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000006.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000007.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000008.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000009.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000010.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000011.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000012.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000014.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000015.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000016.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000017.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/nevus/ISIC_0000018.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024312.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024324.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024336.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024337.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024338.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024358.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024371.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024381.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024382.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024383.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024408.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024409.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024412.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024420.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024422.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/pigmented benign keratosis/ISIC_0024426.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010803.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010808.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/seborrheic keratosis/ISIC_0010809.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011593.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011726.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011750.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0011751.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0012079.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024329.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024372.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024418.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024450.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024463.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024517.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024522.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024539.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024562.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024575.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/squamous cell carcinoma/ISIC_0024579.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024370.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024375.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/vascular lesion/ISIC_0024402.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025780.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025803.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025825.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025953.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025957.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0025992.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026040.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026149.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026171.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026194.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026212.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026457.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026468.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026525.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026575.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026625.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026626.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026650.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026702.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026709.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026729.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026765.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026848.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026857.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026905.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0026984.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027172.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027254.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027334.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027447.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027452.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027536.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027562.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027580.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027615.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027650.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027668.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027802.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027829.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027884.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027896.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027950.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0027958.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028063.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028076.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028190.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028314.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028370.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028393.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028517.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028558.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028820.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028854.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028941.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0028990.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029025.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029041.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029133.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029141.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029210.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029309.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029460.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029500.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029659.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029713.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029781.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029827.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029830.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029840.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029900.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029915.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0029930.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030036.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030133.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030142.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030143.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030242.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030344.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030408.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030463.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030491.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030586.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030655.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030730.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030825.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030826.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0030877.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031040.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031108.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031228.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031292.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031335.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031381.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031430.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031506.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031609.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031823.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031922.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0031993.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032135.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032199.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032206.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032404.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032422.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032437.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0032854.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033151.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033358.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033413.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033456.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033494.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033705.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033811.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/ISIC_0033866.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024504.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024515.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024550.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024564.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024572.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024573.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024582.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024590.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024595.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024632.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024634.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024665.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024666.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024673.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024743.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024787.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024795.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024799.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024829.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024833.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024848.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024885.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024897.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024931.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024949.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0024984.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025019.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025031.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025046.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025102.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025144.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025260.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025266.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025285.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025299.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025301.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025322.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025362.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025383.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025417.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025433.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025467.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025509.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025513.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025530.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025557.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025576.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025601.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025617.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025630.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025644.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025650.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025691.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025700.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025711.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025718.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025731.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025752.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025793.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025818.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025824.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025826.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025932.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025940.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025971.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0025975.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026056.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026074.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026090.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026091.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026117.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026118.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026154.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026192.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026213.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026230.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026275.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026282.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026321.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026324.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026337.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026343.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026350.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026395.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/ISIC_0026433.jpg
# ...
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026456.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026467.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026490.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026693.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026713.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0026876.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027159.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027210.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027256.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027269.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027385.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027522.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027563.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027665.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027672.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027790.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027856.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027888.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027903.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027937.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0027983.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028146.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028163.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028188.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028406.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028431.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028680.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028714.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0028885.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029099.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029404.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029439.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029448.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029486.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029514.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029608.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029742.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029877.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0029889.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030070.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030104.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030275.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030283.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030606.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030722.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030770.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030882.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0030956.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031065.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031090.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031093.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031103.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031197.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031201.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031215.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031217.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031270.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031276.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031346.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031648.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031706.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031719.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031759.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031901.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031950.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031955.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0031996.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032057.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032076.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032240.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032270.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032409.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032538.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032545.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032557.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032614.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032692.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032715.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032745.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032775.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032839.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032866.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032867.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032890.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032919.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0032932.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033031.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033092.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033123.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033135.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033158.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033230.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033254.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033349.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033450.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033458.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033565.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033591.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033608.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033749.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033762.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033817.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033844.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033969.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0033991.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0034196.jpg
#   inflating: /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/ISIC_0034214.jpg
# Extraction Successfull

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %% [markdown]
# ## Step1: Read Data and Create test and train data sets

# %%
# !ls /content/gdrive/MyDrive/DataSets/
# Out:
#  CNN_assignment.zip  'Skin cancer ISIC The International Skin Imaging Collaboration'

# %%
test_directory="/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/"
train_directory="/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/"
print(test_directory, train_directory)
# Out:
# /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Test/ /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/

# %%
# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path(train_directory)
data_dir_test = pathlib.Path(test_directory)

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# # Create a dataset
#
# Define some parameters for the loader:
# ## Step2: Train and Validation data set to trained using batch_size=32 against image dimension 180 x 180

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
# !ls /content/gdrive/MyDrive/DataSets/Skin\ cancer\ ISIC\ The\ International\ Skin\ Imaging\ Collaboration/Train/
# Out:
# 'actinic keratosis'	 melanoma		      'seborrheic keratosis'
# 'basal cell carcinoma'	 nevus			      'squamous cell carcinoma'
#  dermatofibroma		'pigmented benign keratosis'  'vascular lesion'

# %%
## Write your train dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
train_ds = tf.keras.utils.image_dataset_from_directory(
  train_directory,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %%
## Write your validation dataset here
## Note use seed=123 while creating your dataset using tf.keras.preprocessing.image_dataset_from_directory
## Note, make sure your resize your images to the size img_height*img_width, while writting the dataset
val_ds = tf.keras.utils.image_dataset_from_directory(
  train_directory,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %%
# List out all the classes of skin cancer and store them in a list.
# You can find the class names in the class_names attribute on these datasets.
# These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
num_classes = len(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# # Visualize the data
# ## Step3: Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

def displayImage(image):
    plt.imshow(image)
    plt.show()

plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(33):
  for i in range(num_classes):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")


#plt.figure(figsize=(10, 10))
#class_names = train_ds.class_names
#for images, labels in train_ds.take(1):
#    for i in range(32):
#        ax = plt.subplot(6, 6, i + 1)
#        plt.imshow(images[i].numpy().astype("uint8"))
#        plt.title(class_names[labels[i]])
#        plt.axis("off")
### your code goes here, you can use training or validation data to visualize

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: Create a CNN model, which can accurately detect 9 classes present in the dataset. Use ```layers.experimental.preprocessing.Rescaling``` to normalize pixel values between (0,1). The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`
#
# *	Model Building & training :
# *	Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model, rescale images to normalize pixel values between (0,1).
# *	Choose an appropriate optimiser and loss function for model training
# *	Train the model for ~20 epochs
# *	Write your findings after the model fit. You must check if there is any evidence of model overfit or underfit.

# %%
### Your code goes here
normalization_layer = layers.Rescaling(1./255)

# %%
## Resize using Sequential
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(img_height, img_width),
  layers.Rescaling(1./255)
])

# %%
## Build Model for the images

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_2 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 642s 3s/step - loss: 2.0476 - accuracy: 0.2517 - val_loss: 1.8597 - val_accuracy: 0.3244
# Epoch 2/20
# 56/56 [==============================] - 58s 1s/step - loss: 1.7360 - accuracy: 0.3756 - val_loss: 1.5411 - val_accuracy: 0.5302
# Epoch 3/20
# 56/56 [==============================] - 57s 1s/step - loss: 1.4772 - accuracy: 0.4849 - val_loss: 1.5105 - val_accuracy: 0.4899
# Epoch 4/20
# 56/56 [==============================] - 70s 1s/step - loss: 1.3516 - accuracy: 0.5379 - val_loss: 1.3997 - val_accuracy: 0.5145
# Epoch 5/20
# 56/56 [==============================] - 68s 1s/step - loss: 1.2573 - accuracy: 0.5619 - val_loss: 1.3158 - val_accuracy: 0.5369
# Epoch 6/20
# 56/56 [==============================] - 63s 1s/step - loss: 1.1634 - accuracy: 0.5910 - val_loss: 1.4139 - val_accuracy: 0.5302
# Epoch 7/20
# 56/56 [==============================] - 63s 1s/step - loss: 1.0924 - accuracy: 0.6122 - val_loss: 1.4154 - val_accuracy: 0.5459
# Epoch 8/20
# 56/56 [==============================] - 57s 1s/step - loss: 1.1223 - accuracy: 0.6083 - val_loss: 1.3671 - val_accuracy: 0.5391
# Epoch 9/20
# 56/56 [==============================] - 58s 1s/step - loss: 0.9595 - accuracy: 0.6574 - val_loss: 1.3725 - val_accuracy: 0.5257
# Epoch 10/20
# 56/56 [==============================] - 56s 1s/step - loss: 0.9717 - accuracy: 0.6462 - val_loss: 1.4030 - val_accuracy: 0.5324
# Epoch 11/20
# 56/56 [==============================] - 56s 1s/step - loss: 0.9061 - accuracy: 0.6741 - val_loss: 1.5771 - val_accuracy: 0.5257
# Epoch 12/20
# 56/56 [==============================] - 56s 996ms/step - loss: 0.8303 - accuracy: 0.7048 - val_loss: 1.5150 - val_accuracy: 0.5481
# Epoch 13/20
# 56/56 [==============================] - 65s 1s/step - loss: 0.7354 - accuracy: 0.7310 - val_loss: 1.8548 - val_accuracy: 0.4989
# Epoch 14/20
# 56/56 [==============================] - 69s 1s/step - loss: 0.7004 - accuracy: 0.7589 - val_loss: 1.5145 - val_accuracy: 0.5302
# Epoch 15/20
# 56/56 [==============================] - 62s 1s/step - loss: 0.5989 - accuracy: 0.7779 - val_loss: 1.6965 - val_accuracy: 0.5302
# Epoch 16/20
# 56/56 [==============================] - 61s 1s/step - loss: 0.5657 - accuracy: 0.7946 - val_loss: 1.8911 - val_accuracy: 0.5347
# Epoch 17/20
# 56/56 [==============================] - 61s 1s/step - loss: 0.4788 - accuracy: 0.8242 - val_loss: 1.9583 - val_accuracy: 0.5257
# Epoch 18/20
# 56/56 [==============================] - 60s 1s/step - loss: 0.4014 - accuracy: 0.8532 - val_loss: 1.9757 - val_accuracy: 0.5503
# Epoch 19/20
# 56/56 [==============================] - 62s 1s/step - loss: 0.4279 - accuracy: 0.8460 - val_loss: 1.7069 - val_accuracy: 0.5570
# Epoch 20/20
# 56/56 [==============================] - 63s 1s/step - loss: 0.3869 - accuracy: 0.8510 - val_loss: 2.2419 - val_accuracy: 0.5190

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit
#
# The model is working good on Training data set but validation is stuck at just above 0.5, which signifies the model may be overfitting.
#
# Training loss is minimizing with each epoch as training continuous however validation loss has decreased then increased

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# ## 2 Ways to augmente data
# * Use the Keras preprocessing layers, such as tf.keras.layers.Resizing, tf.keras.layers.Rescaling, tf.keras.layers.RandomFlip, and tf.keras.layers.RandomRotation.
# * Use the tf.image methods, such as tf.image.flip_left_right, tf.image.rgb_to_grayscale, tf.image.adjust_brightness, tf.image.central_crop, and tf.image.stateless_random*.
# Setup

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy.
# 2 ways to augmentation data:
# Data augmentation using horizontal and vertical flip
# Your code goes here
data_augmentation = keras.Sequential(
  [
    layers.RandomFlip("horizontal",
                      input_shape=(img_height,
                                  img_width,
                                  3)),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
  ]
)

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.
# Your code goes here
plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here
model = Sequential([
  data_augmentation,
  #layers.Rescaling(1./255),
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes, name="outputs")
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
#model.build(img_height, img_width, 3)

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_11 (Sequential)  (None, 180, 180, 3)       0
#
#  rescaling_11 (Rescaling)    (None, 180, 180, 3)       0
#
#  conv2d_21 (Conv2D)          (None, 180, 180, 16)      448
#
#  max_pooling2d_21 (MaxPooli  (None, 90, 90, 16)        0
#  ng2D)
#
#  conv2d_22 (Conv2D)          (None, 90, 90, 32)        4640
#
#  max_pooling2d_22 (MaxPooli  (None, 45, 45, 32)        0
#  ng2D)
#
#  conv2d_23 (Conv2D)          (None, 45, 45, 64)        18496
#
#  max_pooling2d_23 (MaxPooli  (None, 22, 22, 64)        0
#  ng2D)
#
#  dropout_6 (Dropout)         (None, 22, 22, 64)        0
#
#  flatten_7 (Flatten)         (None, 30976)             0
#
#  dense_8 (Dense)             (None, 128)               3965056
#
#  outputs (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3989801 (15.22 MB)
# Trainable params: 3989801 (15.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 72s 1s/step - loss: 1.9996 - accuracy: 0.2701 - val_loss: 1.7633 - val_accuracy: 0.4094
# Epoch 2/20
# 56/56 [==============================] - 68s 1s/step - loss: 1.6549 - accuracy: 0.4029 - val_loss: 1.5752 - val_accuracy: 0.4631
# Epoch 3/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.5729 - accuracy: 0.4347 - val_loss: 1.5959 - val_accuracy: 0.4497
# Epoch 4/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.5212 - accuracy: 0.4537 - val_loss: 1.5012 - val_accuracy: 0.4787
# Epoch 5/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.4318 - accuracy: 0.4833 - val_loss: 1.4383 - val_accuracy: 0.5168
# Epoch 6/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.3893 - accuracy: 0.5073 - val_loss: 1.4973 - val_accuracy: 0.5034
# Epoch 7/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.3675 - accuracy: 0.5212 - val_loss: 1.4032 - val_accuracy: 0.5391
# Epoch 8/20
# 56/56 [==============================] - 65s 1s/step - loss: 1.2950 - accuracy: 0.5452 - val_loss: 1.3810 - val_accuracy: 0.5280
# Epoch 9/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.2911 - accuracy: 0.5458 - val_loss: 1.3114 - val_accuracy: 0.5391
# Epoch 10/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.2210 - accuracy: 0.5592 - val_loss: 1.3359 - val_accuracy: 0.5347
# Epoch 11/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.2118 - accuracy: 0.5603 - val_loss: 1.3397 - val_accuracy: 0.5235
# Epoch 12/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.2187 - accuracy: 0.5552 - val_loss: 1.4649 - val_accuracy: 0.5034
# Epoch 13/20
# 56/56 [==============================] - 68s 1s/step - loss: 1.1699 - accuracy: 0.5859 - val_loss: 1.3702 - val_accuracy: 0.5280
# Epoch 14/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.1238 - accuracy: 0.5910 - val_loss: 1.2616 - val_accuracy: 0.5615
# Epoch 15/20
# 56/56 [==============================] - 68s 1s/step - loss: 1.1146 - accuracy: 0.5904 - val_loss: 1.3296 - val_accuracy: 0.5369
# Epoch 16/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.1234 - accuracy: 0.5949 - val_loss: 1.3488 - val_accuracy: 0.5481
# Epoch 17/20
# 56/56 [==============================] - 71s 1s/step - loss: 1.0982 - accuracy: 0.6088 - val_loss: 1.3407 - val_accuracy: 0.5414
# Epoch 18/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.0998 - accuracy: 0.6049 - val_loss: 1.2769 - val_accuracy: 0.5749
# Epoch 19/20
# 56/56 [==============================] - 66s 1s/step - loss: 1.0210 - accuracy: 0.6356 - val_loss: 1.3757 - val_accuracy: 0.5369
# Epoch 20/20
# 56/56 [==============================] - 67s 1s/step - loss: 1.0561 - accuracy: 0.6256 - val_loss: 1.3416 - val_accuracy: 0.5593

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?
#
# Training accuracy dropped to 60% however validation accuracy improved to 55%
# Training loss minimized, so is the validation loss.
#
# Model is performing fairly better than 1st model, however still there is scope of improvement

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
# Out:
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)
# (32, 180, 180, 3)
# (32,)

# %%
class_names
# Out:
# ['actinic keratosis',
#  'basal cell carcinoma',
#  'dermatofibroma',
#  'melanoma',
#  'nevus',
#  'pigmented benign keratosis',
#  'seborrheic keratosis',
#  'squamous cell carcinoma',
#  'vascular lesion']

# %%
import glob
path_list_old = [x for x in glob.glob(os.path.join(data_dir_train, '*', '*.jpg'))]
len(path_list_old)
# Out:
# 2239

# %%
lesion_list_old = [os.path.basename(os.path.dirname(y)) for y in glob.glob(os.path.join(data_dir_train, '*', '*.jpg'))]
len(lesion_list_old)
# Out:
# 2239

# %%
print(path_list_old[1333])
print(lesion_list_old[1333])
# Out:
# /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/ISIC_0000537.jpg
# nevus

# %%
dataframe_dict_old = dict(zip(path_list_old, lesion_list_old))

# %%
original_df = pd.DataFrame(list(dataframe_dict_old.items()),columns = ['Path','Label'])
original_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# Name: count, dtype: int64

# %%
original_df.Label.value_counts().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Label'>

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Ans: Seborrheic keratosis has least number of samples
# #### - Which classes dominate the data in terms proportionate number of samples?
# #### - Ans: pigmented benign keratosis and melanoma dominate the samples

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %% [markdown]
# ## Step4: to chose Appropriate Data Augmentation Strategy to resolve underfitting/overfitting
# *	Chose an appropriate data augmentation strategy to resolve underfitting/overfitting
# *	Model Building & training on the augmented data :
# *	Create a CNN model, which can accurately detect 9 classes present in the dataset. While building the model rescale images to normalize pixel values between (0,1).
# *	Choose an appropriate optimiser and loss function for model training
# *	Train the model for ~20 epochs
# *	Write your findings after the model fit, see if the earlier issue is resolved or not?
# *	Class distribution: Examine the current class distribution in the training dataset
# *	- Which class has the least number of samples?
# *	- Which classes dominate the data in terms of the proportionate number of samples?
# *	Handling class imbalances: Rectify class imbalances present in the training dataset with Augmentor library.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.12-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (9.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.4)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.25.2)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.12

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset = train_directory
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7C768C1EBF70>: 100%|██████████| 500/500 [00:23<00:00, 21.48 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768C20BA30>: 100%|██████████| 500/500 [00:23<00:00, 21.21 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768C1BA920>: 100%|██████████| 500/500 [00:26<00:00, 18.89 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7C768C1DF4C0>: 100%|██████████| 500/500 [01:46<00:00,  4.71 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768D381780>: 100%|██████████| 500/500 [01:41<00:00,  4.91 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768C0B7730>: 100%|██████████| 500/500 [00:25<00:00, 19.89 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7C768C1DC1C0>: 100%|██████████| 500/500 [00:50<00:00,  9.90 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768DE5CA90>: 100%|██████████| 500/500 [00:26<00:00, 18.89 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7C768DF29E10>: 100%|██████████| 500/500 [00:24<00:00, 20.20 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
from glob import glob
len(list(glob("/mnt/content/gdrive/*")))
# Out:
# 0

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
#import glob
path_list = [x for x in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
print(len(path_list))
print(path_list[10])
# Out:
# 4500
# /content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0029781.jpg_4d783df1-5f06-49dc-b700-efcca8c51f00.jpg

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob.glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
print(len(lesion_list_new))
print(lesion_list_new[10])
# Out:
# 4500
# actinic keratosis

# %%
dataframe_dict_new = dict(zip(path_list, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = pd.concat([original_df, df2],ignore_index=True)

# %%
new_df['Label'].value_counts()
# Out:
# Label
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: count, dtype: int64

# %%
new_df.Label.value_counts().sort_values().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Label'>

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
#from pathlib import Path
#p = Path(train_directory)
#data_dir_train=[x for x in p.iterdir() if x.is_dir()]
#data_dir_train = [x[0] for x in os.walk(train_directory)]
#print(data_dir_train)
# Out:
# ['/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/actinic keratosis/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/basal cell carcinoma/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/dermatofibroma/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/melanoma/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/nevus/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/pigmented benign keratosis/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/seborrheic keratosis/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/squamous cell carcinoma/output', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion', '/content/gdrive/MyDrive/DataSets/Skin cancer ISIC The International Skin Imaging Collaboration/Train/vascular lesion/output']

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size  =(img_height, img_width),
  batch_size=batch_size)

#train_ds = tf.keras.utils.image_dataset_from_directory(
#  train_directory,
#  validation_split=0.2,
#  subset="training",
#  seed=123,
#  image_size=(img_height, img_width),
#  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_test,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',## Todo choose the correct parameter value, so that only validation data is refered to,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 118 files belonging to 9 classes.
# Using 23 files for validation.

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
### Your code goes here
normalization_layer = layers.Rescaling(1./255)

# %%
## Resize using Sequential
resize_and_rescale = tf.keras.Sequential([
  layers.Resizing(img_height, img_width),
  layers.Rescaling(1./255)
])

# %%
## Build Model for the images

model = Sequential([
  layers.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.BatchNormalization(),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.BatchNormalization(),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling_3 (Rescaling)     (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  batch_normalization (Batch  (None, 180, 180, 16)      64
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 90, 90, 16)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  batch_normalization_1 (Bat  (None, 90, 90, 32)        128
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 45, 45, 32)        0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  batch_normalization_2 (Bat  (None, 45, 45, 64)        256
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 22, 22, 64)        0
#  g2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  batch_normalization_3 (Bat  (None, 128)               512
#  chNormalization)
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3990761 (15.22 MB)
# Trainable params: 3990281 (15.22 MB)
# Non-trainable params: 480 (1.88 KB)
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 30
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 997s 3s/step - loss: 1.5051 - accuracy: 0.4811 - val_loss: 9.7414 - val_accuracy: 0.1351
# Epoch 2/30
# 169/169 [==============================] - 303s 2s/step - loss: 0.9266 - accuracy: 0.6782 - val_loss: 10.3093 - val_accuracy: 0.0638
# Epoch 3/30
# 169/169 [==============================] - 308s 2s/step - loss: 0.5748 - accuracy: 0.8118 - val_loss: 3.1997 - val_accuracy: 0.3831
# Epoch 4/30
# 169/169 [==============================] - 308s 2s/step - loss: 0.3773 - accuracy: 0.8774 - val_loss: 1.0627 - val_accuracy: 0.6221
# Epoch 5/30
# 169/169 [==============================] - 316s 2s/step - loss: 0.2149 - accuracy: 0.9327 - val_loss: 0.6459 - val_accuracy: 0.7862
# Epoch 6/30
# 169/169 [==============================] - 312s 2s/step - loss: 0.1428 - accuracy: 0.9522 - val_loss: 0.6891 - val_accuracy: 0.7817
# Epoch 7/30
# 169/169 [==============================] - 310s 2s/step - loss: 0.1075 - accuracy: 0.9611 - val_loss: 0.9180 - val_accuracy: 0.7402
# Epoch 8/30
# 169/169 [==============================] - 310s 2s/step - loss: 0.0854 - accuracy: 0.9688 - val_loss: 0.6157 - val_accuracy: 0.8411
# Epoch 9/30
# 169/169 [==============================] - 310s 2s/step - loss: 0.0670 - accuracy: 0.9757 - val_loss: 0.8940 - val_accuracy: 0.7587
# Epoch 10/30
# 169/169 [==============================] - 304s 2s/step - loss: 0.0544 - accuracy: 0.9796 - val_loss: 1.3946 - val_accuracy: 0.5954
# Epoch 11/30
# 169/169 [==============================] - 314s 2s/step - loss: 0.0374 - accuracy: 0.9881 - val_loss: 0.6728 - val_accuracy: 0.7988
# Epoch 12/30
# 169/169 [==============================] - 321s 2s/step - loss: 0.0365 - accuracy: 0.9887 - val_loss: 1.2646 - val_accuracy: 0.6466
# Epoch 13/30
# 169/169 [==============================] - 308s 2s/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 1.2034 - val_accuracy: 0.6815
# Epoch 14/30
# 169/169 [==============================] - 307s 2s/step - loss: 0.0288 - accuracy: 0.9922 - val_loss: 0.8658 - val_accuracy: 0.7647
# Epoch 15/30
# 169/169 [==============================] - 302s 2s/step - loss: 0.0229 - accuracy: 0.9933 - val_loss: 0.7807 - val_accuracy: 0.8010
# Epoch 16/30
# 169/169 [==============================] - 309s 2s/step - loss: 0.0478 - accuracy: 0.9868 - val_loss: 4.2791 - val_accuracy: 0.3801
# Epoch 17/30
# 169/169 [==============================] - 309s 2s/step - loss: 0.3263 - accuracy: 0.8872 - val_loss: 3.9400 - val_accuracy: 0.3705
# Epoch 18/30
# 169/169 [==============================] - 314s 2s/step - loss: 0.0954 - accuracy: 0.9703 - val_loss: 0.7023 - val_accuracy: 0.8092
# Epoch 19/30
# 169/169 [==============================] - 304s 2s/step - loss: 0.0384 - accuracy: 0.9892 - val_loss: 0.7688 - val_accuracy: 0.7899
# Epoch 20/30
# 169/169 [==============================] - 306s 2s/step - loss: 0.0171 - accuracy: 0.9954 - val_loss: 0.7107 - val_accuracy: 0.8248
# Epoch 21/30
# 169/169 [==============================] - 306s 2s/step - loss: 0.0088 - accuracy: 0.9989 - val_loss: 0.7975 - val_accuracy: 0.7751
# Epoch 22/30
# 169/169 [==============================] - 299s 2s/step - loss: 0.0066 - accuracy: 0.9993 - val_loss: 0.6650 - val_accuracy: 0.8330
# Epoch 23/30
# 169/169 [==============================] - 297s 2s/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 0.6783 - val_accuracy: 0.8322
# Epoch 24/30
# 169/169 [==============================] - 299s 2s/step - loss: 0.0031 - accuracy: 0.9996 - val_loss: 0.6549 - val_accuracy: 0.8389
# Epoch 25/30
# 169/169 [==============================] - 303s 2s/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.6804 - val_accuracy: 0.8352
# Epoch 26/30
# 169/169 [==============================] - 298s 2s/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.7060 - val_accuracy: 0.8307
# Epoch 27/30
# 169/169 [==============================] - 295s 2s/step - loss: 0.0021 - accuracy: 0.9996 - val_loss: 0.6866 - val_accuracy: 0.8352
# Epoch 28/30
# 169/169 [==============================] - 295s 2s/step - loss: 0.0016 - accuracy: 0.9998 - val_loss: 0.6831 - val_accuracy: 0.8382
# Epoch 29/30
# 169/169 [==============================] - 299s 2s/step - loss: 0.0020 - accuracy: 0.9998 - val_loss: 0.7483 - val_accuracy: 0.8263
# Epoch 30/30
# 169/169 [==============================] - 286s 2s/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.7031 - val_accuracy: 0.8411

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?
# * Both Test and Validation accuracy are improved to 80%, pointing to model not underfitting / overfitting
# * Validation loss is greatly reduced on accuracy
# * Handling the class imbalance through augmentation helped to get rid of underfitting or overfitting in the training data set.
